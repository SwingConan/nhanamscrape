# %%
import pandas as pd
df = pd.read_csv('nhanamspider.csv')
df
# Out:
#           barcode            category  \
# 0    893606669817       Thể Loại Khác
# 1    893606669988           Thiếu Nhi
# 2    893606669987           Thiếu Nhi
# 3    893606669990           Thiếu Nhi
# 4    893606669989           Thiếu Nhi
# ..            ...                 ...
# 995  893497420235  Truyện Tranh/Manga
# 996  893497420234  Truyện Tranh/Manga
# 997  893532501965        Tuổi Mới Lớn
# 998  893532502104    Kỹ Năng/Sống Đẹp
# 999  893532502042             Văn Học
#
#                                            description  \
# 0                                                  NaN
# 1                         Cuốn sách nằm trong bộ sách
# 2                         Cuốn sách nằm trong bộ sách
# 3                         Cuốn sách nằm trong bộ sách
# 4                         Cuốn sách nằm trong bộ sách
# ..                                                 ...
# 995  Bút Chì hết sợ bị đau, sợ bị mòn, lại sợ bị ng...
# 996  Kéo vừa có chiếc nón mới nên hí hửng đội đi  k...
# ...
